# %% [markdown]
# <a href="https://colab.research.google.com/github/NMapelu/2.-Graphics-API/blob/master/AirlineChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

REPO_URL = "https://github.com/NMapelu/AirlineChatbot.git"
PROJECT_DIR = "/content/AirlineChatbot"   # Linux path — Colab's working area

if not os.path.exists(PROJECT_DIR):
    # !git clone {REPO_URL} {PROJECT_DIR}
else:
    # !cd {PROJECT_DIR} && git pull

os.chdir(PROJECT_DIR)
print("Working directory:", os.getcwd())
# !ls -la
# Out:
# Already up to date.
# Working directory: /content/AirlineChatbot
# total 24
# drwxr-xr-x 3 root root 4096 Sep 18 00:44 .
# drwxr-xr-x 1 root root 4096 Sep 18 00:44 ..
# drwxr-xr-x 8 root root 4096 Sep 18 00:47 .git
# -rw-r--r-- 1 root root  289 Sep 18 00:44 .gitignore
# -rw-r--r-- 1 root root   16 Sep 18 00:44 README.md
# -rw-r--r-- 1 root root   42 Sep 18 00:44 requirements.txt

# %%
# !pip install -q -r requirements.txt

# %%
import os

# Where your persistent data lives in Google Drive
DRIVE_ROOT = "/content/drive/MyDrive/AirlineChatbot"
os.makedirs(f"{DRIVE_ROOT}/data", exist_ok=True)
os.makedirs(f"{DRIVE_ROOT}/checkpoints", exist_ok=True)
os.makedirs(f"{DRIVE_ROOT}/outputs", exist_ok=True)

# Export for your code to pick up
os.environ["PROJECT_DRIVE"] = DRIVE_ROOT
os.environ["PROJECT_LOCAL"] = PROJECT_DIR

print("Drive root:", DRIVE_ROOT)
# Out:
# Drive root: /content/drive/MyDrive/AirlineChatbot

# %%
# Your training / model code here.
# Save checkpoints to f"{DRIVE_ROOT}/checkpoints/"
